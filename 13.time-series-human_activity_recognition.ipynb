# %%
# !nvidia-smi
# Out:
# Sat Feb 11 00:09:47 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 522.06       Driver Version: 522.06       CUDA Version: 11.8     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   53C    P0    26W /  N/A |   5280MiB /  6144MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1924      C   ...nvs\tensorflow\python.exe    N/A      |
# |    0   N/A  N/A      2000    C+G   ...ightStudio-background.exe    N/A      |
# |    0   N/A  N/A      4608    C+G   ...wekyb3d8bbwe\Video.UI.exe    N/A      |
# |    0   N/A  N/A      5208    C+G   ...icrosoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A      6220    C+G   ...cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A      7604    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A      8152    C+G   ...tracted\WechatBrowser.exe    N/A      |
# |    0   N/A  N/A      9300    C+G   ...me\Application\chrome.exe    N/A      |
# |    0   N/A  N/A     10852    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A     12240    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     14652    C+G   ...ystemEventUtilityHost.exe    N/A      |
# |    0   N/A  N/A     17752    C+G   ...6\extracted\WeChatApp.exe    N/A      |
# |    0   N/A  N/A     20184    C+G   ...8wekyb3d8bbwe\Cortana.exe    N/A      |
# |    0   N/A  N/A     20360    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     20492    C+G   ...aming\Spotify\Spotify.exe    N/A      |
# |    0   N/A  N/A     20944    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     25700    C+G   ...mmandCenterBackground.exe    N/A      |
# |    0   N/A  N/A     29304    C+G   ...dows\System32\WWAHost.exe    N/A      |
# |    0   N/A  N/A     30840    C+G   ...jag6ke6\HP.JumpStarts.exe    N/A      |
# |    0   N/A  N/A     31236    C+G   ...ge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     33000      C   ...nvs\tensorflow\python.exe    N/A      |
# |    0   N/A  N/A     33036      C   ...nvs\tensorflow\python.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
# !pip install gdown
# !pip install tensorflow-gpu
# Out:
# Requirement already satisfied: gdown in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (4.6.0)
# Requirement already satisfied: six in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from gdown) (4.64.1)
# Requirement already satisfied: requests[socks] in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from gdown) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from gdown) (4.11.1)
# Requirement already satisfied: filelock in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from gdown) (3.9.0)
# Requirement already satisfied: soupsieve>1.2 in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: idna<4,>=2.5 in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from requests[socks]->gdown) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from requests[socks]->gdown) (2.1.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in d:\anacondamachinelearn\main\envs\tensorflow\lib\site-packages (from tqdm->gdown) (0.4.6)
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting python_version>"3.7"
#   Downloading python_version-0.0.2-py2.py3-none-any.whl (3.4 kB)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py): started
#   Building wheel for tensorflow-gpu (setup.py): finished with status 'error'
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# Installing collected packages: python_version, tensorflow-gpu
#   Running setup.py install for tensorflow-gpu: started
#   Running setup.py install for tensorflow-gpu: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\hp\AppData\Local\Temp\pip-install-yuzdly_i\tensorflow-gpu_0981136d98114025907940311b90faaf\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tensorflow-gpu
#   error: subprocess-exited-with-error
#
#   Running setup.py install for tensorflow-gpu did not run successfully.
#   exit code: 1
#
#   [18 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\hp\AppData\Local\Temp\pip-install-yuzdly_i\tensorflow-gpu_0981136d98114025907940311b90faaf\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# tensorflow-gpu
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from pandas.plotting import register_matplotlib_converters

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 22, 10

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
#!gdown --id 152sWECukjvLerrVG2NUO8gtMFg83RKCF --output WISDM_ar_latest.tar.gz
#!tar -xvf WISDM_ar_latest.tar.gz

# %%
column_names = ['user_id', 'activity', 'timestamp', 'x_axis', 'y_axis', 'z_axis']

df = pd.read_csv('WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt', header=None, names=column_names)
df.sb.replace(regex=True, inplace=True, to_replace=r';', value=r'')
df['z_axis'] = df.z_axis.astype(np.float64)
df.dropna(axis=0, how='any', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14084\3798977469.py in <module>
#       1 column_names = ['user_id', 'activity', 'timestamp', 'x_axis', 'y_axis', 'z_axis']
#       2
# ----> 3 df = pd.read_csv('WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt', header=None, names=column_names)
#       4 df.sb.replace(regex=True, inplace=True, to_replace=r';', value=r'')
#       5 df['z_axis'] = df.z_axis.astype(np.float64)
#
# D:\Anacondamachinelearn\Main\envs\tensorflow\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# D:\Anacondamachinelearn\Main\envs\tensorflow\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# D:\Anacondamachinelearn\Main\envs\tensorflow\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# D:\Anacondamachinelearn\Main\envs\tensorflow\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     609
#     610     with parser:
# --> 611         return parser.read(nrows)
#     612
#     613
#
# D:\Anacondamachinelearn\Main\envs\tensorflow\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1776                     columns,
#    1777                     col_dict,
# -> 1778                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1779                     nrows
#    1780                 )
#
# D:\Anacondamachinelearn\Main\envs\tensorflow\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     228         try:
#     229             if self.low_memory:
# --> 230                 chunks = self._reader.read_low_memory(nrows)
#     231                 # destructive to chunks
#     232                 data = _concatenate_chunks(chunks)
#
# D:\Anacondamachinelearn\Main\envs\tensorflow\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# D:\Anacondamachinelearn\Main\envs\tensorflow\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# D:\Anacondamachinelearn\Main\envs\tensorflow\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# D:\Anacondamachinelearn\Main\envs\tensorflow\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 6 fields in line 832907, saw 7

# %%
df.head()
# Out:
#    user_id activity       timestamp    x_axis     y_axis    z_axis
# 0       33  Jogging  49105962326000 -0.694638  12.680544  0.503953
# 1       33  Jogging  49106062271000  5.012288  11.264028  0.953424
# 2       33  Jogging  49106112167000  4.903325  10.882658 -0.081722
# 3       33  Jogging  49106222305000 -0.612916  18.496431  3.023717
# 4       33  Jogging  49106332290000 -1.184970  12.108489  7.205164

# %%
df.shape
# Out:
# (1098203, 6)

# %%
sns.countplot(x = 'activity',
              data = df,
              order = df.activity.value_counts().index);

# %%
sns.countplot(x = 'user_id',
              data = df,
              palette=[sns.color_palette()[0]],
              order = df.user_id.value_counts().index);
plt.title("Records per user");

# %%
def plot_activity(activity, df):
    data = df[df['activity'] == activity][['x_axis', 'y_axis', 'z_axis']][:200]
    axis = data.plot(subplots=True, figsize=(16, 12), 
                     title=activity)
    for ax in axis:
        ax.legend(loc='lower left', bbox_to_anchor=(1.0, 0.5))

# %%
plot_activity("Sitting", df);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14084\190150917.py in <module>
# ----> 1 plot_activity("Sitting", df);
#
# NameError: name 'df' is not defined

# %%
plot_activity("Jogging", df);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14084\3642466767.py in <module>
# ----> 1 plot_activity("Jogging", df);
#
# NameError: name 'df' is not defined

# %%
df_train = df[df['user_id'] <= 30]
df_test = df[df['user_id'] > 30]

# %%
from sklearn.preprocessing import RobustScaler

scale_columns = ['x_axis', 'y_axis', 'z_axis']

scaler = RobustScaler()

scaler = scaler.fit(df_train[scale_columns])

df_train.loc[:, scale_columns] = scaler.transform(df_train[scale_columns].to_numpy())
df_test.loc[:, scale_columns] = scaler.transform(df_test[scale_columns].to_numpy())
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
from scipy import stats

def create_dataset(X, y, time_steps=1, step=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        v = X.iloc[i:(i + time_steps)].values
        labels = y.iloc[i: i + time_steps]
        Xs.append(v)        
        ys.append(stats.mode(labels)[0][0])
    return np.array(Xs), np.array(ys).reshape(-1, 1)

TIME_STEPS = 200
STEP = 40

X_train, y_train = create_dataset(
    df_train[['x_axis', 'y_axis', 'z_axis']], 
    df_train.activity, 
    TIME_STEPS, 
    STEP
)

X_test, y_test = create_dataset(
    df_test[['x_axis', 'y_axis', 'z_axis']], 
    df_test.activity, 
    TIME_STEPS, 
    STEP
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16760\2244104431.py in <module>
#      14
#      15 X_train, y_train = create_dataset(
# ---> 16     df_train[['x_axis', 'y_axis', 'z_axis']],
#      17     df_train.activity,
#      18     TIME_STEPS,
#
# NameError: name 'df_train' is not defined

# %%
print(X_train.shape, y_train.shape)
# Out:
# (22454, 200, 3) (22454, 1)

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unknown='ignore', sparse=False)

enc = enc.fit(y_train)

y_train = enc.transform(y_train)
y_test = enc.transform(y_test)

# %%
print(X_train.shape, y_train.shape)
print(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16760\3040722895.py in <module>
# ----> 1 print(X_train.shape, y_train.shape)
#       2 print(X_train)
#
# NameError: name 'X_train' is not defined

# %%
model = keras.Sequential()
model.add(
    keras.layers.Bidirectional(
      keras.layers.LSTM(
          units=128, 
          input_shape=[X_train.shape[1], X_train.shape[2]]
      )
    )
)
model.add(keras.layers.Dropout(rate=0.5))
model.add(keras.layers.Dense(units=128, activation='relu'))
model.add(keras.layers.Dense(y_train.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

# %%
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=64,
    validation_split=0.1,
    shuffle=True
)
# Out:
# Train on 20208 samples, validate on 2246 samples
# Epoch 1/20
# 20208/20208 [==============================] - 229s 11ms/sample - loss: 1.0116 - acc: 0.6550 - val_loss: 0.8067 - val_acc: 0.7471
# Epoch 2/20
# 20208/20208 [==============================] - 229s 11ms/sample - loss: 0.6785 - acc: 0.7595 - val_loss: 0.6865 - val_acc: 0.7783
# Epoch 3/20
# 20208/20208 [==============================] - 226s 11ms/sample - loss: 0.5842 - acc: 0.7900 - val_loss: 0.5044 - val_acc: 0.8402
# Epoch 4/20
# 20208/20208 [==============================] - 226s 11ms/sample - loss: 0.4848 - acc: 0.8201 - val_loss: 0.6837 - val_acc: 0.8228
# Epoch 5/20
# 20208/20208 [==============================] - 229s 11ms/sample - loss: 0.4291 - acc: 0.8410 - val_loss: 0.4128 - val_acc: 0.8549
# Epoch 6/20
# 20208/20208 [==============================] - 226s 11ms/sample - loss: 0.3836 - acc: 0.8588 - val_loss: 0.3750 - val_acc: 0.8664
# Epoch 7/20
# 20208/20208 [==============================] - 226s 11ms/sample - loss: 0.3014 - acc: 0.8899 - val_loss: 0.4904 - val_acc: 0.8197
# Epoch 8/20
# 20208/20208 [==============================] - 225s 11ms/sample - loss: 0.6424 - acc: 0.7739 - val_loss: 0.5422 - val_acc: 0.8308
# Epoch 9/20
# 20208/20208 [==============================] - 225s 11ms/sample - loss: 0.6336 - acc: 0.7742 - val_loss: 0.5323 - val_acc: 0.8482
# Epoch 10/20
# 20208/20208 [==============================] - 225s 11ms/sample - loss: 0.4216 - acc: 0.8378 - val_loss: 0.4312 - val_acc: 0.8513
# Epoch 11/20
# 20208/20208 [==============================] - 225s 11ms/sample - loss: 0.3946 - acc: 0.8476 - val_loss: 0.6927 - val_acc: 0.7743
# Epoch 12/20
# 20208/20208 [==============================] - 225s 11ms/sample - loss: 0.3518 - acc: 0.8714 - val_loss: 0.5952 - val_acc: 0.8455
# Epoch 13/20
# 20208/20208 [==============================] - 227s 11ms/sample - loss: 0.4773 - acc: 0.8244 - val_loss: 0.4993 - val_acc: 0.8152
# Epoch 14/20
# 20208/20208 [==============================] - 223s 11ms/sample - loss: 0.4979 - acc: 0.8185 - val_loss: 0.6019 - val_acc: 0.8148
# Epoch 15/20
# 20208/20208 [==============================] - 226s 11ms/sample - loss: 0.3340 - acc: 0.8755 - val_loss: 0.5336 - val_acc: 0.8299
# Epoch 16/20
# 20208/20208 [==============================] - 224s 11ms/sample - loss: 0.4807 - acc: 0.8242 - val_loss: 0.4978 - val_acc: 0.8179
# Epoch 17/20
# 20208/20208 [==============================] - 221s 11ms/sample - loss: 0.4303 - acc: 0.8391 - val_loss: 0.4010 - val_acc: 0.8687
# Epoch 18/20
# 20208/20208 [==============================] - 223s 11ms/sample - loss: 0.4551 - acc: 0.8352 - val_loss: 0.6171 - val_acc: 0.8139
# Epoch 19/20
# 20208/20208 [==============================] - 230s 11ms/sample - loss: 0.4544 - acc: 0.8353 - val_loss: 0.4714 - val_acc: 0.8482
# Epoch 20/20
# 20208/20208 [==============================] - 228s 11ms/sample - loss: 0.3387 - acc: 0.8765 - val_loss: 0.4232 - val_acc: 0.8936

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend();

# %%
model.evaluate(X_test, y_test)
# Out:
# 4992/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.3619675412960649, 0.8790064]

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

def plot_cm(y_true, y_pred, class_names):
  cm = confusion_matrix(y_true, y_pred)
  fig, ax = plt.subplots(figsize=(18, 16)) 
  ax = sns.heatmap(
      cm, 
      annot=True, 
      fmt="d", 
      cmap=sns.diverging_palette(220, 20, n=7),
      ax=ax
  )

  plt.ylabel('Actual')
  plt.xlabel('Predicted')
  ax.set_xticklabels(class_names)
  ax.set_yticklabels(class_names)
  b, t = plt.ylim() # discover the values for bottom and top
  b += 0.5 # Add 0.5 to the bottom
  t -= 0.5 # Subtract 0.5 from the top
  plt.ylim(b, t) # update the ylim(bottom, top) values
  plt.show() # ta-da!

# %%
plot_cm(
  enc.inverse_transform(y_test),
  enc.inverse_transform(y_pred),
  enc.categories_[0]
)
